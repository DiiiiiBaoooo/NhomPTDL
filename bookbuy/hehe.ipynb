# %%
import pandas as pd

# %%
df=pd.read_csv('bookbuy/spiders\csvdatabookbuy.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\This PC\AppData\Local\Temp\ipykernel_3188\2391532853.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df=pd.read_csv('bookbuy/spiders\csvdatabookbuy.csv')

# %%
df
# Out:
#                 Author                                          Book_name  \
# 0       Lyle & Michael  Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1        Oprah Winfrey            Những Điều Tôi Biết Chắc (Tái Bản 2018)
# 2     George Macdonald                                   Sau Lưng Gió Bấc
# 3      Fiona MacDonald                    Sẽ Ra Sao Nếu Thiếu Nhà Vệ Sinh
# 4         Amanda Huynh                                                Lam
# ...                ...                                                ...
# 1267      Kudoh Noriko                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268         Trường An                                   Hồ Dương - Tâp 1
# 1269      Karen Dillon                HBR Guide To - Sống Sót Nơi Công Sở
# 1270    Porter Erisman                       Thế Giới Alibaba Của Jack Ma
# 1271       Lê Anh Vinh              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content      Issuiers  \
# 0     là tập 3 của bộ truyện tranh Giáng sinh ở thàn...      Văn Việt
# 1     Lắm lúc một câu trả lời chẳng phải dễ kiếm ra....    Alphabooks
# 2     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...       Nhã Nam
# 3     Bạn sẽ " giải quyết nỗi buồn" thế nào nếu khôn...  NXB Kim Đồng
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...       NXB Trẻ
# ...                                                 ...           ...
# 1267                                       chiếp chiếp.       Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...    NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;    Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...       NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...       Thái Hà
#
#       Market_Price Num_Page   Price Publish_date          Publisher    Status  \
# 0            90000      210   72000   12/07/2016        NXB Văn Học  Còn hàng
# 1            99000      232   84000   12/01/2018       NXB Thế Giới  Hết hàng
# 2            90000      420   76500   13/07/2016  NXB Hội Nhà Văn  Hết hàng
# 3            22000     Đang   18500   11/07/2016       NXB Kim Đồng  Hết hàng
# 4            85000      164   72000   14/07/2016            NXB Trẻ  Hết hàng
# ...            ...      ...     ...          ...                ...       ...
# 1267         44000       32   37000   22/09/2017       NXB Thế Giới  Hết hàng
# 1268        217000      728  184000   01/09/2017         NXB Phụ Nữ  Hết hàng
# 1269         99000      228   84000   22/09/2017       NXB Thế Giới  Hết hàng
# 1270        105000      322   89000   01/09/2017            NXB Trẻ  Hết hàng
# 1271         49000       34   41500   10/10/2017       NXB Thế Giới  Hết hàng
#
#      Weight
# 0       310
# 1       450
# 2       650
# 3       200
# 4       300
# ...     ...
# 1267    200
# 1268    950
# 1269    370
# 1270    522
# 1271    184
#
# [1272 rows x 11 columns]

# %%
df.isna().any()
# Out:
# Author           True
# Book_name       False
# Content          True
# Issuiers        False
# Market_Price    False
# Num_Page        False
# Price           False
# Publish_date    False
# Publisher       False
# Status          False
# Weight          False
# dtype: bool

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index            Author  \
# 0         0    Lyle & Michael
# 1         1     Oprah Winfrey
# 2         2  George Macdonald
# 3         3   Fiona MacDonald
# 4         4      Amanda Huynh
# ...     ...               ...
# 1267   1267      Kudoh Noriko
# 1268   1268         Trường An
# 1269   1269      Karen Dillon
# 1270   1270    Porter Erisman
# 1271   1271       Lê Anh Vinh
#
#                                               Book_name  \
# 0     Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1               Những Điều Tôi Biết Chắc (Tái Bản 2018)
# 2                                      Sau Lưng Gió Bấc
# 3                       Sẽ Ra Sao Nếu Thiếu Nhà Vệ Sinh
# 4                                                   Lam
# ...                                                 ...
# 1267                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268                                   Hồ Dương - Tâp 1
# 1269                HBR Guide To - Sống Sót Nơi Công Sở
# 1270                       Thế Giới Alibaba Của Jack Ma
# 1271              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content      Issuiers  \
# 0     là tập 3 của bộ truyện tranh Giáng sinh ở thàn...      Văn Việt
# 1     Lắm lúc một câu trả lời chẳng phải dễ kiếm ra....    Alphabooks
# 2     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...       Nhã Nam
# 3     Bạn sẽ " giải quyết nỗi buồn" thế nào nếu khôn...  NXB Kim Đồng
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...       NXB Trẻ
# ...                                                 ...           ...
# 1267                                       chiếp chiếp.       Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...    NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;    Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...       NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...       Thái Hà
#
#       Market_Price Num_Page   Price Publish_date          Publisher    Status  \
# 0            90000      210   72000   12/07/2016        NXB Văn Học  Còn hàng
# 1            99000      232   84000   12/01/2018       NXB Thế Giới  Hết hàng
# 2            90000      420   76500   13/07/2016  NXB Hội Nhà Văn  Hết hàng
# 3            22000     Đang   18500   11/07/2016       NXB Kim Đồng  Hết hàng
# 4            85000      164   72000   14/07/2016            NXB Trẻ  Hết hàng
# ...            ...      ...     ...          ...                ...       ...
# 1267         44000       32   37000   22/09/2017       NXB Thế Giới  Hết hàng
# 1268        217000      728  184000   01/09/2017         NXB Phụ Nữ  Hết hàng
# 1269         99000      228   84000   22/09/2017       NXB Thế Giới  Hết hàng
# 1270        105000      322   89000   01/09/2017            NXB Trẻ  Hết hàng
# 1271         49000       34   41500   10/10/2017       NXB Thế Giới  Hết hàng
#
#      Weight
# 0       310
# 1       450
# 2       650
# 3       200
# 4       300
# ...     ...
# 1267    200
# 1268    950
# 1269    370
# 1270    522
# 1271    184
#
# [1272 rows x 12 columns]

# %%
df['Status'] = df['Status'].apply(lambda x: 0 if x == 'Hết hàng' else 1)

# %%
df
# Out:
#       index            Author  \
# 0         0    Lyle & Michael
# 1         1     Oprah Winfrey
# 2         2  George Macdonald
# 3         3   Fiona MacDonald
# 4         4      Amanda Huynh
# ...     ...               ...
# 1267   1267      Kudoh Noriko
# 1268   1268         Trường An
# 1269   1269      Karen Dillon
# 1270   1270    Porter Erisman
# 1271   1271       Lê Anh Vinh
#
#                                               Book_name  \
# 0     Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1               Những Điều Tôi Biết Chắc (Tái Bản 2018)
# 2                                      Sau Lưng Gió Bấc
# 3                       Sẽ Ra Sao Nếu Thiếu Nhà Vệ Sinh
# 4                                                   Lam
# ...                                                 ...
# 1267                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268                                   Hồ Dương - Tâp 1
# 1269                HBR Guide To - Sống Sót Nơi Công Sở
# 1270                       Thế Giới Alibaba Của Jack Ma
# 1271              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content      Issuiers  \
# 0     là tập 3 của bộ truyện tranh Giáng sinh ở thàn...      Văn Việt
# 1     Lắm lúc một câu trả lời chẳng phải dễ kiếm ra....    Alphabooks
# 2     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...       Nhã Nam
# 3     Bạn sẽ " giải quyết nỗi buồn" thế nào nếu khôn...  NXB Kim Đồng
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...       NXB Trẻ
# ...                                                 ...           ...
# 1267                                       chiếp chiếp.       Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...    NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;    Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...       NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...       Thái Hà
#
#       Market_Price Num_Page   Price Publish_date          Publisher  Status  \
# 0            90000      210   72000   12/07/2016        NXB Văn Học       1
# 1            99000      232   84000   12/01/2018       NXB Thế Giới       0
# 2            90000      420   76500   13/07/2016  NXB Hội Nhà Văn       0
# 3            22000     Đang   18500   11/07/2016       NXB Kim Đồng       0
# 4            85000      164   72000   14/07/2016            NXB Trẻ       0
# ...            ...      ...     ...          ...                ...     ...
# 1267         44000       32   37000   22/09/2017       NXB Thế Giới       0
# 1268        217000      728  184000   01/09/2017         NXB Phụ Nữ       0
# 1269         99000      228   84000   22/09/2017       NXB Thế Giới       0
# 1270        105000      322   89000   01/09/2017            NXB Trẻ       0
# 1271         49000       34   41500   10/10/2017       NXB Thế Giới       0
#
#      Weight
# 0       310
# 1       450
# 2       650
# 3       200
# 4       300
# ...     ...
# 1267    200
# 1268    950
# 1269    370
# 1270    522
# 1271    184
#
# [1272 rows x 12 columns]

# %%
df['Status'] .value_counts()
# Out:
# Status
# 0    1224
# 1      48
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             index  Market_Price         Price       Status
# count  1272.00000  1.272000e+03  1.272000e+03  1272.000000
# mean    635.50000  9.153105e+04  7.754481e+04     0.037736
# std     367.33908  9.135878e+04  7.768013e+04     0.190632
# min       0.00000  1.000000e+04  7.500000e+03     0.000000
# 25%     317.75000  5.200000e+04  4.400000e+04     0.000000
# 50%     635.50000  7.900000e+04  6.700000e+04     0.000000
# 75%     953.25000  1.090000e+05  9.250000e+04     0.000000
# max    1271.00000  2.000000e+06  1.700000e+06     1.000000
